# %%
import pandas as pd

# %%
schema_df = pd.read_csv('survey_results_public.csv')

# %%
schema_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
pd.set_option('display.max_columns', 56)

# %%
pd.set_option('display.max_rows', 85)

# %%
schema_df = pd.read_csv('survey_results_public.csv')

# %%
schema_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
schema_df.head(50)
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1                     I am a developer by profession      Yes
# 1            2                     I am a developer by profession       No
# 2            3                        I code primarily as a hobby      Yes
# 3            4                     I am a developer by profession      Yes
# 4            5  I used to be a developer by profession, but no...      Yes
# 5            6                     I am a developer by profession       No
# 6            7                     I am a developer by profession      Yes
# 7            8                     I am a developer by profession      Yes
# 8            9                     I am a developer by profession       No
# 9           10                     I am a developer by profession      Yes
# 10          11                     I am a developer by profession      Yes
# ...

# %%
schema_df['Age'].head(50)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3     25.0
# 4     31.0
# 5      NaN
# 6      NaN
# 7     36.0
# 8     30.0
# 9     22.0
# 10    23.0
# 11    49.0
# 12    53.0
# 13    27.0
# 14     NaN
# 15    45.0
# 16    25.0
# 17    32.0
# 18    24.0
# 19    40.0
# 20    23.0
# 21     NaN
# 22    27.0
# 23    45.0
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28    18.0
# 29     NaN
# 30     NaN
# 31    31.0
# 32    39.0
# 33    29.0
# 34    16.0
# 35    34.0
# 36    19.0
# 37    35.0
# 38     NaN
# 39    20.0
# 40     NaN
# 41    32.0
# 42     NaN
# 43    32.0
# 44    22.0
# 45    24.0
# 46    53.0
# 47    38.0
# 48    23.0
# 49    57.0
# Name: Age, dtype: float64

# %%
na_values=['NA', 'Missing', 'No value']

# %%
schema_df['YearsCode'].head(50)
# Out:
# 0                   36
# 1                    7
# 2                    4
# 3                    7
# 4                   15
# 5                    6
# 6                    6
# 7                   17
# 8                    6
# 9                    8
# 10                  10
# 11                   7
# 12                  35
# 13                   5
# 14                   4
# 15                  37
# 16                   7
# 17                  19
# 18                   9
# 19                  22
# 20                   7
# 21                  10
# 22                   8
# 23                  30
# 24                  23
# 25                  17
# 26                  20
# 27                   2
# 28    Less than 1 year
# 29                   4
# 30                   6
# 31                  19
# 32                  20
# 33                  10
# 34                   3
# 35                   4
# 36                   2
# 37                  20
# 38                  13
# 39                   6
# ...

# %%
schema_df['YearsCode'].replace('Less than 1 year', 0, inplace=True)

# %%
schema_df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
schema_df['YearsCode'].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 0, '3', '13', '25', '16', '43',
#        '11', '38', '33', nan, '24', '21', '12', '40', '27', '50', '46',
#        '14', '18', '28', '32', '44', '26', '42', '31', '34', '29', '1',
#        '39', '41', '45', 51, '47', '49', '48'], dtype=object)

# %%
schema_df['YearsCode'] = schema_df['YearsCode'].astype(float)

# %%
schema_df['YearsCode'].mean()
# Out:
# 12.709052770265584

# %%
schema_df['YearsCode'].median()
# Out:
# 10.0

# %%
schema_df['YearsCode'].shape
# Out:
# (64461,)

# %%
schema_df['YearsCode'].dropna()
# Out:
# 0        36.0
# 1         7.0
# 2         4.0
# 3         7.0
# 4        15.0
#          ...
# 64449     0.0
# 64451     2.0
# 64453     3.0
# 64454     3.0
# 64456    10.0
# Name: YearsCode, Length: 57684, dtype: float64

# %%
schema_df.describe()
# Out:
#          Respondent           Age      CompTotal  ConvertedComp   WorkWeekHrs  \
# count  64461.000000  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean   32554.079738     30.834111  3.190464e+242   1.037561e+05     40.782174
# std    18967.442360      9.585392            inf   2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%    32231.000000     29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%    49142.000000     35.000000   1.250000e+05   9.500000e+04     44.000000
# max    65639.000000    279.000000  1.111111e+247   2.000000e+06    475.000000
#
#           YearsCode
# count  57684.000000
# mean      12.709053
# std        9.717353
# min        0.000000
# 25%        6.000000
# 50%       10.000000
# 75%       17.000000
# max       51.000000

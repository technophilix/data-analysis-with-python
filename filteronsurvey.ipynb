# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                                   C#;HTML/CSS;JavaScript
# 2                                         JavaScript;Swift
# 3                                 Objective-C;Python;Swift
# 4                                                      NaN
# 5                                        HTML/CSS;Ruby;SQL
#                                ...
# 64858                                                  NaN
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                  NaN
# 64925                                             HTML/CSS
# 65112                      C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 64461, dtype: object

# %%
filt = (df['LanguageWorkedWith'].str.contains('Python', na=False)) & (df['Gender']== 'Man')

# %%
df.loc[filt]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 8                              I am a developer by profession      Yes  36.0
# 10                             I am a developer by profession      Yes  22.0
# 13          I am not primarily a developer, but I write co...      Yes  53.0
# 15                     I am a student who is learning to code      Yes   NaN
# 17                             I am a developer by profession      Yes  25.0
# ...                                                       ...      ...   ...
# 61111                                                     NaN      Yes  38.0
# 61490                                                     NaN      Yes   NaN
# 61561                                                     NaN      Yes  64.0
# 62391                                                     NaN      Yes   NaN
# 63640                                                     NaN      Yes   NaN
#
# ...

# %%
high_salary = df['ConvertedComp'] > 30000

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith']]
# Out:
#                    Country                   LanguageWorkedWith
# Respondent
# 8            United States                           Python;SQL
# 10          United Kingdom  HTML/CSS;Java;JavaScript;Python;SQL
# 11          United Kingdom                  C#;JavaScript;Swift
# 12                   Spain                  HTML/CSS;JavaScript
# 13             Netherlands                  C;JavaScript;Python
# ...                    ...                                  ...
# 65611              Denmark                                  NaN
# 65617              Germany                                  NaN
# 65625             Colombia                                  NaN
# 65630                Chile                                  NaN
# 65631                Japan                                  NaN
#
# [33880 rows x 2 columns]

# %%
countries = ['India', 'United States', 'Canada']

# %%
country_filt = df['Country'].isin(countries)

# %%
df.loc[country_filt, 'Country']
# Out:
# Respondent
# 5        United States
# 7                India
# 8        United States
# 14       United States
# 17       United States
#              ...
# 62834           Canada
# 62954            India
# 63077    United States
# 64236            India
# 64858    United States
# Name: Country, Length: 23063, dtype: object

# %%
compl_filt = (df['ConvertedComp'] > 30000) & (df['Country'].isin(countries)) & (df['LanguageWorkedWith'].str.contains('Python', na=False))

# %%
df.loc[compl_filt]
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 8           I am a developer by profession      Yes  36.0         12   Yearly
# 17          I am a developer by profession      Yes  25.0         14   Yearly
# 26          I am a developer by profession       No   NaN         12   Yearly
# 32          I am a developer by profession      Yes  31.0         12  Monthly
# 42          I am a developer by profession       No  32.0         14   Yearly
# ...                                    ...      ...   ...        ...      ...
# 65502       I am a developer by profession      Yes   NaN         11   Weekly
# 65523       I am a developer by profession      Yes   NaN         18  Monthly
# 65527       I am a developer by profession      Yes   NaN         11  Monthly
# 65528       I am a developer by profession       No   NaN         16   Yearly
# 65596       I am a developer by profession      Yes   NaN         22   Yearly
#
# ...

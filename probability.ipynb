# %%
import random
import matplotlib.pyplot as plt
n = int(input("enter a number"));

heads_frq = []
tail_frq = []
for i in range(1,n):
    samples = [ random.randint(0, 1) for i in range(100) ]
    heads = samples.count(0)
    tails = samples.count(1)
    heads_frq.append(heads/100)
    
plt.plot(range(1,n), heads_frq)
plt.show()
# Out:
# enter a number 1000

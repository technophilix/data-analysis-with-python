# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df

# %%
df.shape # shape is an attribute
# Out:
# (64461, 61)

# %%
df.head()

# %%
df.tail()

# %%
df[16:45]

# %%
df['Age']

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
schema_df
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 644)

# %%
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# 27                     NEWDevOps
# 28                 NEWDevOpsImpt
# 29                     NEWEdImpt
# 30                    NEWJobHunt
# 31            NEWJobHuntResearch
# 32                      NEWLearn
# 33                   NEWOffTopic
# 34                NEWOnboardGood
# 35                 NEWOtherComms
# 36                   NEWOvertime
# 37           NEWPurchaseResearch
# 38                 NEWPurpleLink
# 39                    NEWSOSites
# 40                      NEWStuck
# 41                         OpSys
# 42                       OrgSize
# 43        PlatformDesireNextYear
# 44            PlatformWorkedWith
# 45                  PurchaseWhat
# 46                     Sexuality
# 47                     SOAccount
# 48                        SOComm
# 49                    SOPartFreq
# 50                   SOVisitFreq
# 51                    SurveyEase
# 52                  SurveyLength
# 53                         Trans
# 54                UndergradMajor
# 55        WebframeDesireNextYear
# 56            WebframeWorkedWith
# 57                 WelcomeChange
# 58                   WorkWeekHrs
# 59                     YearsCode
# 60                  YearsCodePro
#
#                                          QuestionText
# 0   Randomized respondent ID number (not in order ...
# 1   Which of the following options best describes ...
# 2                             Do you code as a hobby?
# 3   What is your age (in years)? If you prefer not...
# 4   At what age did you write your first line of c...
# 5    Is that compensation weekly, monthly, or yearly?
# 6   What is your current total compensation (salar...
# 7   Salary converted to annual USD salaries using ...
# 8                                  Where do you live?
# 9   Which currency do you use day-to-day? If your ...
# 10  Which currency do you use day-to-day? If your ...
# 11  Which database environments have you done exte...
# 12  Which database environments have you done exte...
# 13  Which of the following describe you? Please se...
# 14  Which of the following best describes the high...
# 15  Which of the following best describes your cur...
# 16  Which of the following describe you, if any? P...
# 17  Which of the following describe you, if any? P...
# 18  Imagine that you are deciding between two job ...
# 19  How satisfied are you with your current job? (...
# 20  Which of the following best describes your cur...
# 21  Which programming, scripting, and markup langu...
# 22  Which programming, scripting, and markup langu...
# 23  Which other frameworks, libraries, and tools h...
# 24  Which other frameworks, libraries, and tools h...
# 25  Which collaboration tools have you done extens...
# 26  Which collaboration tools have you done extens...
# 27  Does your company have a dedicated DevOps person?
# 28  How important is the practice of DevOps to sca...
# 29  How important is a formal education, such as a...
# 30  In general, what drives you to look for a new ...
# 31  When job searching, how do you learn more abou...
# 32  How frequently do you learn a new language or ...
# 33  Do you think Stack Overflow should relax restr...
# 34  Do you think your company has a good onboardin...
# 35  Are you a member of any other online developer...
# 36  How often do you work overtime or beyond the f...
# 37  When buying a new tool or software, how do you...
# 38  You search for a coding solution online and th...
# 39  Which of the following Stack Overflow sites ha...
# 40  What do you do when you get stuck on a problem...
# 41  What is the primary operating system in which ...
# 42  Approximately how many people are employed by ...
# 43  Which platforms have you done extensive develo...
# 44  Which platforms have you done extensive develo...
# 45  What level of influence do you, personally, ha...
# 46  Which of the following describe you, if any? P...
# 47              Do you have a Stack Overflow account?
# 48  Do you consider yourself a member of the Stack...
# 49  How frequently would you say you participate i...
# 50  How frequently would you say you visit Stack O...
# 51  How easy or difficult was this survey to compl...
# 52  How do you feel about the length of the survey...
# 53                               Are you transgender?
# 54              What was your primary field of study?
# 55  Which web frameworks have you done extensive d...
# 56  Which web frameworks have you done extensive d...
# 57  Compared to last year, how welcome do you feel...
# 58  On average, how many hours per week do you wor...
# 59  Including any education, how many years have y...
# 60  NOT including education, how many years have y...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df.loc[[0,1,2,3]]
# Out:
#    Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 0           1  I am a developer by profession      Yes   NaN         13
# 1           2  I am a developer by profession       No   NaN         19
# 2           3     I code primarily as a hobby      Yes   NaN         15
# 3           4  I am a developer by profession      Yes  25.0         18
#
#   CompFreq  CompTotal  ConvertedComp             Country    CurrencyDesc  \
# 0  Monthly        NaN            NaN             Germany   European Euro
# 1      NaN        NaN            NaN      United Kingdom  Pound sterling
# 2      NaN        NaN            NaN  Russian Federation             NaN
# 3      NaN        NaN            NaN             Albania    Albanian lek
#
#   CurrencySymbol DatabaseDesireNextYear  \
# 0            EUR   Microsoft SQL Server
# 1            GBP                    NaN
# 2            NaN                    NaN
# 3            ALL                    NaN
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
# 1            Developer, full-stack;Developer, mobile
# 2                                                NaN
# 3                                                NaN
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                              NaN
# 3  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Employed full-time
# 2                                                NaN
# 3                                                NaN
#
#                       Ethnicity Gender  \
# 0  White or of European descent    Man
# 1                           NaN    NaN
# 2                           NaN    NaN
# 3  White or of European descent    Man
#
#                                           JobFactors                 JobSat  \
# 0  Languages, frameworks, and other technologies ...     Slightly satisfied
# 1                                                NaN      Very dissatisfied
# 2                                                NaN                    NaN
# 3  Flex time or a flexible schedule;Office enviro...  Slightly dissatisfied
#
#                                              JobSeek  \
# 0       I am not interested in new job opportunities
# 1       I am not interested in new job opportunities
# 2                                                NaN
# 3  I’m not actively looking, but I am open to new...
#
#      LanguageDesireNextYear        LanguageWorkedWith  \
# 0    C#;HTML/CSS;JavaScript    C#;HTML/CSS;JavaScript
# 1              Python;Swift          JavaScript;Swift
# 2  Objective-C;Python;Swift  Objective-C;Python;Swift
# 3                       NaN                       NaN
#
#              MiscTechDesireNextYear MiscTechWorkedWith  \
# 0                 .NET Core;Xamarin     .NET;.NET Core
# 1  React Native;TensorFlow;Unity 3D       React Native
# 2                               NaN                NaN
# 3                               NaN                NaN
#
#              NEWCollabToolsDesireNextYear  \
# 0  Microsoft Teams;Microsoft Azure;Trello
# 1                            Github;Slack
# 2                                     NaN
# 3                                     NaN
#
#                        NEWCollabToolsWorkedWith NEWDevOps       NEWDevOpsImpt  \
# 0  Confluence;Jira;Slack;Microsoft Azure;Trello        No  Somewhat important
# 1           Confluence;Jira;Github;Gitlab;Slack       NaN                 NaN
# 2                                           NaN       NaN                 NaN
# 3                                           NaN        No                 NaN
#
#                             NEWEdImpt  \
# 0                    Fairly important
# 1                    Fairly important
# 2                                 NaN
# 3  Not at all important/not necessary
#
#                                           NEWJobHunt NEWJobHuntResearch  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3  Curious about other opportunities;Wanting to w...                NaN
#
#         NEWLearn NEWOffTopic NEWOnboardGood NEWOtherComms  \
# 0    Once a year    Not sure            NaN            No
# 1    Once a year    Not sure            NaN            No
# 2  Once a decade         NaN            NaN            No
# 3    Once a year    Not sure            Yes           Yes
#
#                                          NEWOvertime  \
# 0                   Often: 1-2 days per week or more
# 1                                                NaN
# 2                                                NaN
# 3  Occasionally: 1-2 days per quarter but less th...
#
#                                  NEWPurchaseResearch NEWPurpleLink  \
# 0  Start a free trial;Ask developers I know/work ...        Amused
# 1                                                NaN        Amused
# 2                                                NaN           NaN
# 3                                                NaN           NaN
#
#                                           NEWSOSites  \
# 0   Stack Overflow (public Q&A for anyone who codes)
# 1  Stack Overflow (public Q&A for anyone who code...
# 2   Stack Overflow (public Q&A for anyone who codes)
# 3  Stack Overflow (public Q&A for anyone who code...
#
#                                             NEWStuck        OpSys  \
# 0  Visit Stack Overflow;Go for a walk or other ph...      Windows
# 1  Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 2                                                NaN  Linux-based
# 3                                                NaN  Linux-based
#
#                     OrgSize                          PlatformDesireNextYear  \
# 0          2 to 9 employees  Android;iOS;Kubernetes;Microsoft Azure;Windows
# 1  1,000 to 4,999 employees                      iOS;Kubernetes;Linux;MacOS
# 2                       NaN                                             NaN
# 3        20 to 99 employees                                             NaN
#
#   PlatformWorkedWith                      PurchaseWhat  \
# 0            Windows                               NaN
# 1                iOS     I have little or no influence
# 2                NaN                               NaN
# 3                NaN  I have a great deal of influence
#
#                  Sexuality SOAccount           SOComm  \
# 0  Straight / Heterosexual        No   No, not at all
# 1                      NaN       Yes  Yes, definitely
# 2                      NaN       Yes    Yes, somewhat
# 3  Straight / Heterosexual       Yes  Yes, definitely
#
#                             SOPartFreq             SOVisitFreq  \
# 0                                  NaN  Multiple times per day
# 1  Less than once per month or monthly  Multiple times per day
# 2      A few times per month or weekly   Daily or almost daily
# 3      A few times per month or weekly  Multiple times per day
#
#                    SurveyEase           SurveyLength Trans  \
# 0  Neither easy nor difficult  Appropriate in length    No
# 1                         NaN                    NaN   NaN
# 2  Neither easy nor difficult  Appropriate in length   NaN
# 3                         NaN                    NaN    No
#
#                                       UndergradMajor WebframeDesireNextYear  \
# 0  Computer science, computer engineering, or sof...           ASP.NET Core
# 1  Computer science, computer engineering, or sof...                    NaN
# 2                                                NaN                    NaN
# 3  Computer science, computer engineering, or sof...                    NaN
#
#      WebframeWorkedWith                             WelcomeChange  \
# 0  ASP.NET;ASP.NET Core   Just as welcome now as I felt last year
# 1                   NaN  Somewhat more welcome now than last year
# 2                   NaN  Somewhat more welcome now than last year
# 3                   NaN  Somewhat less welcome now than last year
#
#    WorkWeekHrs YearsCode YearsCodePro
# 0         50.0        36           27
# 1          NaN         7            4
# 2          NaN         4          NaN
# 3         40.0         7            4

# %%
df.loc[16:45]
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 16          17                     I am a developer by profession      Yes
# 17          18                     I am a developer by profession      Yes
# 18          19                     I am a developer by profession       No
# 19          20                     I am a developer by profession      Yes
# 20          21             I am a student who is learning to code      Yes
# 21          22                     I am a developer by profession      Yes
# 22          23                     I am a developer by profession      Yes
# 23          24                     I am a developer by profession      Yes
# 24          25                     I am a developer by profession       No
# 25          26                     I am a developer by profession       No
# 26          27  I used to be a developer by profession, but no...      Yes
# 27          28             I am a student who is learning to code      Yes
# 28          29             I am a student who is learning to code      Yes
# 29          30                     I am a developer by profession      Yes
# 30          31                     I am a developer by profession      Yes
# 31          32                     I am a developer by profession      Yes
# 32          33                     I am a developer by profession      Yes
# 33          34                     I am a developer by profession      Yes
# 34          35             I am a student who is learning to code      Yes
# 35          36  I am not primarily a developer, but I write co...      Yes
# 36          37                     I am a developer by profession      Yes
# 37          38                     I am a developer by profession       No
# 38          39  I am not primarily a developer, but I write co...      Yes
# 39          40             I am a student who is learning to code      Yes
# 40          41                     I am a developer by profession       No
# 41          42                     I am a developer by profession       No
# 42          43                     I am a developer by profession      Yes
# 43          44                     I am a developer by profession       No
# 44          45                     I am a developer by profession      Yes
# 45          46                     I am a developer by profession      Yes
#
#      Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 16  25.0         14   Yearly    79000.0        79000.0       United States
# 17  32.0         12  Monthly   105000.0      1260000.0       United States
# 18  24.0         15   Yearly    83400.0        83400.0       United States
# 19  40.0         18      NaN        NaN            NaN               Spain
# 20  23.0         16      NaN        NaN            NaN             Belgium
# 21   NaN         18  Monthly        NaN            NaN               India
# 22  27.0         14      NaN        NaN            NaN             Germany
# 23  45.0         14   Yearly    85000.0        91883.0             Germany
# 24   NaN         25  Monthly        NaN            NaN            Portugal
# 25   NaN         12   Yearly    94000.0        71093.0              Canada
# 26   NaN         12      NaN        NaN            NaN       United States
# 27   NaN         22      NaN        NaN            NaN               China
# 28  18.0         15      NaN        NaN            NaN             Ukraine
# 29   NaN         14   Yearly    30000.0        38778.0      United Kingdom
# 30   NaN         20   Weekly        NaN            NaN  Russian Federation
# 31  31.0         12  Monthly     3500.0        31764.0              Canada
# 32  39.0         14  Monthly     4900.0        63564.0             Belgium
# 33  29.0         15      NaN        NaN            NaN             Germany
# 34  16.0         13      NaN        NaN            NaN       United States
# 35  34.0         30   Yearly    60000.0        77556.0      United Kingdom
# 36  19.0         16  Monthly        NaN            NaN              France
# 37  35.0         14   Yearly    90000.0        97288.0               Italy
# 38   NaN         17      NaN        NaN            NaN      United Kingdom
# 39  20.0         14      NaN        NaN            NaN       United States
# 40   NaN         15   Yearly   106000.0       106000.0       United States
# 41  32.0         14   Yearly   130000.0       130000.0       United States
# 42   NaN         16   Yearly   135000.0       135000.0       United States
# 43  32.0         21   Yearly   244000.0        55893.0              Brazil
# 44  22.0         13   Yearly    34000.0        36753.0              France
# 45  24.0         14   Yearly    35000.0        37834.0              France
#
#             CurrencyDesc CurrencySymbol  \
# 16  United States dollar            USD
# 17  United States dollar            USD
# 18  United States dollar            USD
# 19         European Euro            EUR
# 20                   NaN            NaN
# 21          Indian rupee            INR
# 22         European Euro            EUR
# 23         European Euro            EUR
# 24         European Euro            EUR
# 25       Canadian dollar            CAD
# 26                   NaN            NaN
# 27                   NaN            NaN
# 28                   NaN            NaN
# 29        Pound sterling            GBP
# 30     Australian dollar            AUD
# 31       Canadian dollar            CAD
# 32         European Euro            EUR
# 33                   NaN            NaN
# 34                   NaN            NaN
# 35        Pound sterling            GBP
# 36         European Euro            EUR
# 37         European Euro            EUR
# 38        Pound sterling            GBP
# 39                   NaN            NaN
# 40  United States dollar            USD
# 41  United States dollar            USD
# 42  United States dollar            USD
# 43        Brazilian real            BRL
# 44         European Euro            EUR
# 45         European Euro            EUR
#
#                                DatabaseDesireNextYear  \
# 16   Cassandra;Elasticsearch;MariaDB;PostgreSQL;Redis
# 17              Elasticsearch;PostgreSQL;Redis;SQLite
# 18                                    MariaDB;MongoDB
# 19                                                NaN
# 20                           Firebase;MariaDB;MongoDB
# 21                                                NaN
# 22                                                NaN
# 23                               Cassandra;PostgreSQL
# 24                                     MariaDB;Oracle
# 25                                                NaN
# 26                                  PostgreSQL;SQLite
# 27                                                NaN
# 28                     MySQL;Oracle;PostgreSQL;SQLite
# 29                                   Firebase;MongoDB
# 30                                                NaN
# 31                                       MySQL;SQLite
# 32                                            MongoDB
# 33                        Elasticsearch;MongoDB;Redis
# 34                                      MongoDB;MySQL
# 35                Microsoft SQL Server;MongoDB;SQLite
# 36                                      Elasticsearch
# 37                           MongoDB;PostgreSQL;Redis
# 38                                                NaN
# 39                                              MySQL
# 40                               Microsoft SQL Server
# 41                         Cassandra;DynamoDB;MongoDB
# 42                                             Oracle
# 43                               Microsoft SQL Server
# 44                              Elasticsearch;MongoDB
# 45  Elasticsearch;Microsoft SQL Server;MongoDB;MyS...
#
#                                    DatabaseWorkedWith  \
# 16                    Microsoft SQL Server;PostgreSQL
# 17           Elasticsearch;MariaDB;MySQL;Redis;SQLite
# 18                       MariaDB;Microsoft SQL Server
# 19         IBM DB2;MariaDB;Microsoft SQL Server;MySQL
# 20  Firebase;MariaDB;Microsoft SQL Server;MongoDB;...
# 21                                                NaN
# 22                                                NaN
# 23                                  PostgreSQL;SQLite
# 24                                             Oracle
# 25                                         PostgreSQL
# 26              Elasticsearch;MySQL;PostgreSQL;SQLite
# 27                                                NaN
# 28                                                NaN
# 29                  Microsoft SQL Server;Redis;SQLite
# 30                                                NaN
# 31                                       MySQL;SQLite
# 32                    MongoDB;MySQL;PostgreSQL;SQLite
# 33                                 MongoDB;PostgreSQL
# 34                                      MongoDB;MySQL
# 35        IBM DB2;Microsoft SQL Server;MongoDB;SQLite
# 36                   MariaDB;MongoDB;MySQL;PostgreSQL
# 37                           MongoDB;PostgreSQL;Redis
# 38                                                NaN
# 39                                       MySQL;SQLite
# 40                               Microsoft SQL Server
# 41            Microsoft SQL Server;MySQL;Oracle;Redis
# 42                                             Oracle
# 43                               Microsoft SQL Server
# 44                        Elasticsearch;MongoDB;MySQL
# 45  Microsoft SQL Server;MongoDB;MySQL;PostgreSQL;...
#
#                                               DevType  \
# 16                              Developer, full-stack
# 17                                Developer, back-end
# 18                              Developer, full-stack
# 19      Developer, desktop or enterprise applications
# 20                                                NaN
# 21               Developer, full-stack;Engineer, data
# 22  Developer, back-end;Developer, desktop or ente...
# 23                                Developer, back-end
# 24  Developer, back-end;Developer, full-stack;DevO...
# 25                              Developer, full-stack
# 26  Database administrator;Developer, full-stack;E...
# 27                                                NaN
# 28                                                NaN
# 29  Data or business analyst;Database administrato...
# 30                                Academic researcher
# 31  Developer, back-end;Developer, desktop or ente...
# 32  Developer, front-end;Developer, full-stack;Dev...
# 33          Developer, back-end;Developer, full-stack
# 34                      Designer;Developer, front-end
# 35  Data or business analyst;Data scientist or mac...
# 36                               Developer, front-end
# 37          Developer, full-stack;Engineering manager
# 38                                                NaN
# 39                                                NaN
# 40  Developer, back-end;Developer, front-end;Devel...
# 41  Developer, back-end;Developer, desktop or ente...
# 42  Developer, back-end;Developer, front-end;Devel...
# 43  Data or business analyst;Developer, back-end;P...
# 44                              Developer, full-stack
# 45  Developer, back-end;Developer, desktop or ente...
#
#                                               EdLevel  \
# 16       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 17       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 18       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 19       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 20  Secondary school (e.g. American high school, G...
# 21       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 22       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 23                 Professional degree (JD, MD, etc.)
# 24                Associate degree (A.A., A.S., etc.)
# 25       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 26       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 27  Some college/university study without earning ...
# 28  Secondary school (e.g. American high school, G...
# 29       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 30    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 31       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 32       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 33    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 34       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 35  Some college/university study without earning ...
# 36                Associate degree (A.A., A.S., etc.)
# 37       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 38       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 39                Associate degree (A.A., A.S., etc.)
# 40    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 41       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 42    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 43    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 44    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 45    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                            Employment  \
# 16                                 Employed full-time
# 17                                 Employed full-time
# 18                                 Employed full-time
# 19                                 Employed full-time
# 20                                            Student
# 21                                 Employed full-time
# 22                                 Employed full-time
# 23                                 Employed full-time
# 24                                 Employed full-time
# 25                                 Employed full-time
# 26                                 Employed full-time
# 27                                            Student
# 28                                            Student
# 29                                 Employed full-time
# 30                                 Employed full-time
# 31                                 Employed full-time
# 32                                 Employed full-time
# 33                 Not employed, but looking for work
# 34                 Not employed, but looking for work
# 35                                 Employed full-time
# 36                                 Employed full-time
# 37                                 Employed full-time
# 38  Independent contractor, freelancer, or self-em...
# 39                                            Student
# 40                                 Employed full-time
# 41                                 Employed full-time
# 42                                 Employed full-time
# 43                                 Employed full-time
# 44                                 Employed full-time
# 45                                 Employed full-time
#
#                        Ethnicity Gender  \
# 16  White or of European descent    Man
# 17  White or of European descent    Man
# 18  White or of European descent    Man
# 19        Hispanic or Latino/a/x    Man
# 20  White or of European descent    Man
# 21                           NaN    Man
# 22  White or of European descent    Man
# 23  White or of European descent    Man
# 24        Hispanic or Latino/a/x    Man
# 25                    East Asian    Man
# 26  White or of European descent    Man
# 27   Black or of African descent    Man
# 28                           NaN    Man
# 29                           NaN    Man
# 30                    East Asian    Man
# 31  White or of European descent    Man
# 32  White or of European descent    Man
# 33  White or of European descent    Man
# 34  White or of European descent  Woman
# 35  White or of European descent    Man
# 36                Middle Eastern    Man
# 37  White or of European descent    Man
# 38  White or of European descent    NaN
# 39        Hispanic or Latino/a/x  Woman
# 40                           NaN    NaN
# 41  White or of European descent    Man
# 42                           NaN    NaN
# 43  White or of European descent    Man
# 44  White or of European descent    Man
# 45  White or of European descent    Man
#
#                                            JobFactors  \
# 16  Industry that I’d be working in;Languages, fra...
# 17  Languages, frameworks, and other technologies ...
# 18  Flex time or a flexible schedule;Office enviro...
# 19                                                NaN
# 20  Languages, frameworks, and other technologies ...
# 21                                                NaN
# 22  Flex time or a flexible schedule;Languages, fr...
# 23  Languages, frameworks, and other technologies ...
# 24  Languages, frameworks, and other technologies ...
# 25  Flex time or a flexible schedule;Remote work o...
# 26                                                NaN
# 27  Diversity of the company or organization;Langu...
# 28  Specific department or team I’d be working on;...
# 29  Languages, frameworks, and other technologies ...
# 30                                                NaN
# 31  Flex time or a flexible schedule;Languages, fr...
# 32  Flex time or a flexible schedule;Remote work o...
# 33  Flex time or a flexible schedule;Languages, fr...
# 34  Flex time or a flexible schedule;Remote work o...
# 35  Flex time or a flexible schedule;Office enviro...
# 36  Languages, frameworks, and other technologies ...
# 37  Flex time or a flexible schedule;Remote work o...
# 38  Industry that I’d be working in;Office environ...
# 39  Industry that I’d be working in;Flex time or a...
# 40  Remote work options;Financial performance or f...
# 41  Remote work options;How widely used or impactf...
# 42                                                NaN
# 43  Industry that I’d be working in;Specific depar...
# 44  Languages, frameworks, and other technologies ...
# 45  Industry that I’d be working in;Specific depar...
#
#                                 JobSat  \
# 16               Slightly dissatisfied
# 17                      Very satisfied
# 18               Slightly dissatisfied
# 19  Neither satisfied nor dissatisfied
# 20                                 NaN
# 21               Slightly dissatisfied
# 22                      Very satisfied
# 23                      Very satisfied
# 24  Neither satisfied nor dissatisfied
# 25  Neither satisfied nor dissatisfied
# 26                                 NaN
# 27                                 NaN
# 28                                 NaN
# 29               Slightly dissatisfied
# 30                  Slightly satisfied
# 31                  Slightly satisfied
# 32               Slightly dissatisfied
# 33                                 NaN
# 34                                 NaN
# 35                  Slightly satisfied
# 36                      Very satisfied
# 37                      Very satisfied
# 38                   Very dissatisfied
# 39                                 NaN
# 40               Slightly dissatisfied
# 41                      Very satisfied
# 42                   Very dissatisfied
# 43  Neither satisfied nor dissatisfied
# 44                      Very satisfied
# 45                  Slightly satisfied
#
#                                               JobSeek  \
# 16  I’m not actively looking, but I am open to new...
# 17       I am not interested in new job opportunities
# 18  I’m not actively looking, but I am open to new...
# 19  I’m not actively looking, but I am open to new...
# 20  I’m not actively looking, but I am open to new...
# 21                    I am actively looking for a job
# 22       I am not interested in new job opportunities
# 23       I am not interested in new job opportunities
# 24  I’m not actively looking, but I am open to new...
# 25  I’m not actively looking, but I am open to new...
# 26                                                NaN
# 27  I’m not actively looking, but I am open to new...
# 28  I’m not actively looking, but I am open to new...
# 29  I’m not actively looking, but I am open to new...
# 30       I am not interested in new job opportunities
# 31  I’m not actively looking, but I am open to new...
# 32  I’m not actively looking, but I am open to new...
# 33                    I am actively looking for a job
# 34  I’m not actively looking, but I am open to new...
# 35  I’m not actively looking, but I am open to new...
# 36       I am not interested in new job opportunities
# 37       I am not interested in new job opportunities
# 38  I’m not actively looking, but I am open to new...
# 39  I’m not actively looking, but I am open to new...
# 40  I’m not actively looking, but I am open to new...
# 41  I’m not actively looking, but I am open to new...
# 42       I am not interested in new job opportunities
# 43  I’m not actively looking, but I am open to new...
# 44  I’m not actively looking, but I am open to new...
# 45  I’m not actively looking, but I am open to new...
#
#                                LanguageDesireNextYear  \
# 16  C#;Go;Haskell;HTML/CSS;JavaScript;Python;Ruby;...
# 17                                      HTML/CSS;Perl
# 18                            C#;Go;Python;TypeScript
# 19                                                 Go
# 20  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Scala;S...
# 21                             Java;JavaScript;Python
# 22                                             C#;C++
# 23  Bash/Shell/PowerShell;Go;Java;Julia;Kotlin;Pyt...
# 24                   Assembly;Bash/Shell/PowerShell;C
# 25                                            Go;Rust
# 26        Bash/Shell/PowerShell;C;C++;Perl;Python;SQL
# 27                                                NaN
# 28  C#;HTML/CSS;Java;JavaScript;Kotlin;Python;SQL;...
# 29                          JavaScript;SQL;TypeScript
# 30                                                NaN
# 31                                         C++;Python
# 32                     HTML/CSS;JavaScript;TypeScript
# 33                                      Go;TypeScript
# 34              HTML/CSS;JavaScript;Python;TypeScript
# 35               C#;Go;HTML/CSS;JavaScript;Python;SQL
# 36                                        Dart;Python
# 37                         JavaScript;Rust;TypeScript
# 38                                                 C#
# 39                      C#;HTML/CSS;JavaScript;Python
# 40                                      C;C#;Java;SQL
# 41       Bash/Shell/PowerShell;C#;Go;Java;Python;Rust
# 42                  Dart;HTML/CSS;Java;JavaScript;SQL
# 43              HTML/CSS;Java;JavaScript;Python;R;SQL
# 44                                   Java;Python;Rust
# 45                                   C#;C++;Go;Python
#
#                                    LanguageWorkedWith  \
# 16              C#;HTML/CSS;JavaScript;Python;SQL;VBA
# 17                Bash/Shell/PowerShell;HTML/CSS;Perl
# 18  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...
# 19                                Java;JavaScript;SQL
# 20  Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 21                                        Java;Python
# 22                       Bash/Shell/PowerShell;C#;C++
# 23          Bash/Shell/PowerShell;Java;Kotlin;PHP;SQL
# 24                            Bash/Shell/PowerShell;C
# 25                                  JavaScript;Python
# 26        Bash/Shell/PowerShell;C;C++;Java;Python;SQL
# 27                                           Python;R
# 28                             C#;C++;HTML/CSS;Python
# 29  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 30                                              C;C++
# 31                          C;C++;Java;Python;SQL;VBA
# 32                     HTML/CSS;JavaScript;TypeScript
# 33            HTML/CSS;Java;JavaScript;SQL;TypeScript
# 34                      HTML/CSS;Java;JavaScript;Ruby
# 35        C#;Go;HTML/CSS;Java;JavaScript;Python;R;SQL
# 36  Bash/Shell/PowerShell;Haskell;HTML/CSS;JavaScr...
# 37               HTML/CSS;JavaScript;Python;Ruby;Rust
# 38                                          C#;Python
# 39        C;C#;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 40                                      C;C#;Java;SQL
# 41  Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 42                  Dart;HTML/CSS;Java;JavaScript;SQL
# 43                          HTML/CSS;Python;R;SQL;VBA
# 44  Bash/Shell/PowerShell;C;C++;Java;JavaScript;Py...
# 45                       Bash/Shell/PowerShell;C#;C++
#
#                                MiscTechDesireNextYear  \
# 16                                 .NET Core;Teraform
# 17                                                NaN
# 18        Node.js;React Native;Unity 3D;Unreal Engine
# 19                                         TensorFlow
# 20                               Node.js;React Native
# 21                                                NaN
# 22                                          .NET Core
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                         TensorFlow
# 27                                                NaN
# 28  .NET;.NET Core;Node.js;Pandas;Unity 3D;Unreal ...
# 29                                            Node.js
# 30                                                NaN
# 31                                                NaN
# 32                      Node.js;React Native;Unity 3D
# 33                       Flutter;Node.js;React Native
# 34                                            Node.js
# 35                    Keras;Node.js;Pandas;TensorFlow
# 36                                         TensorFlow
# 37                                   Node.js;Teraform
# 38                                           Unity 3D
# 39                             Unity 3D;Unreal Engine
# 40                             .NET;.NET Core;Node.js
# 41                                 .NET Core;Teraform
# 42                                            Flutter
# 43                                                NaN
# 44                                                NaN
# 45                            .NET;.NET Core;Unity 3D
#
#                    MiscTechWorkedWith  \
# 16                       .NET;Node.js
# 17                                NaN
# 18             .NET;.NET Core;Node.js
# 19                            Node.js
# 20      Node.js;React Native;Unity 3D
# 21                                NaN
# 22                               .NET
# 23                                NaN
# 24                                NaN
# 25                                NaN
# 26                                NaN
# 27                             Pandas
# 28                               .NET
# 29                            Node.js
# 30  TensorFlow;Torch/PyTorch;Unity 3D
# 31                                NaN
# 32               Node.js;React Native
# 33                            Node.js
# 34               Node.js;React Native
# 35                     Node.js;Pandas
# 36               Node.js;React Native
# 37                   Node.js;Teraform
# 38                           Unity 3D
# 39        .NET;Unity 3D;Unreal Engine
# 40                        .NET;Hadoop
# 41    .NET;.NET Core;Node.js;Teraform
# 42                            Flutter
# 43                                NaN
# 44            Ansible;Cordova;Node.js
# 45            .NET;.NET Core;Unity 3D
#
#                          NEWCollabToolsDesireNextYear  \
# 16  Github;Gitlab;Slack;Google Suite (Docs, Meet, ...
# 17                                             Github
# 18                                       Github;Slack
# 19                                             Github
# 20       Github;Trello;Google Suite (Docs, Meet, etc)
# 21                                                NaN
# 22                             Confluence;Jira;Github
# 23      Confluence;Jira;Github;Gitlab;Microsoft Teams
# 24  Jira;Github;Gitlab;Slack;Stack Overflow for Teams
# 25                                                NaN
# 26       Github;Gitlab;Google Suite (Docs, Meet, etc)
# 27                                                NaN
# 28                               Github;Gitlab;Trello
# 29                                  Jira;Github;Slack
# 30                                                NaN
# 31               Jira;Github;Stack Overflow for Teams
# 32  Github;Slack;Google Suite (Docs, Meet, etc);St...
# 33                                      Github;Gitlab
# 34                                             Github
# 35                Confluence;Jira;Github;Slack;Trello
# 36                                                NaN
# 37        Github;Slack;Google Suite (Docs, Meet, etc)
# 38                                                NaN
# 39  Jira;Github;Gitlab;Slack;Trello;Google Suite (...
# 40                                    Microsoft Teams
# 41                             Confluence;Jira;Gitlab
# 42                                        Jira;Github
# 43                                Github;Slack;Trello
# 44                                       Gitlab;Slack
# 45                       Github;Slack;Microsoft Azure
#
#                              NEWCollabToolsWorkedWith NEWDevOps  \
# 16  Github;Gitlab;Slack;Microsoft Teams;Google Sui...       Yes
# 17                                       Github;Slack  Not sure
# 18                       Confluence;Jira;Github;Slack       Yes
# 19                                        Jira;Github       Yes
# 20  Github;Gitlab;Trello;Google Suite (Docs, Meet,...       NaN
# 21                                                NaN  Not sure
# 22                             Confluence;Jira;Github        No
# 23  Confluence;Jira;Github;Gitlab;Slack;Microsoft ...  Not sure
# 24                                 Jira;Github;Gitlab        No
# 25  Jira;Github;Gitlab;Slack;Google Suite (Docs, M...       Yes
# 26  Jira;Github;Gitlab;Microsoft Teams;Trello;Goog...       NaN
# 27                                      Github;Gitlab       NaN
# 28                                      Github;Trello       NaN
# 29                             Confluence;Jira;Github        No
# 30                                      Github;Gitlab       Yes
# 31                                        Jira;Github  Not sure
# 32  Confluence;Jira;Github;Gitlab;Slack;Google Sui...       Yes
# 33                           Confluence;Github;Gitlab       NaN
# 34                                      Github;Trello       NaN
# 35                Confluence;Jira;Github;Slack;Trello  Not sure
# 36  Confluence;Jira;Github;Gitlab;Slack;Microsoft ...       Yes
# 37        Github;Slack;Google Suite (Docs, Meet, etc)       Yes
# 38                                             Github       NaN
# 39  Confluence;Jira;Github;Gitlab;Slack;Trello;Goo...       NaN
# 40                       Slack;Microsoft Teams;Trello        No
# 41  Confluence;Jira;Github;Gitlab;Slack;Trello;Goo...       Yes
# 42                                        Jira;Github       Yes
# 43                                Github;Slack;Trello        No
# 44  Github;Gitlab;Slack;Microsoft Teams;Google Sui...       Yes
# 45                       Github;Slack;Microsoft Azure        No
#
#           NEWDevOpsImpt                           NEWEdImpt  \
# 16  Extremely important                    Fairly important
# 17              Neutral                      Very important
# 18  Extremely important                    Fairly important
# 19              Neutral                      Very important
# 20                  NaN                                 NaN
# 21                  NaN                      Very important
# 22              Neutral                    Fairly important
# 23   Somewhat important                      Very important
# 24  Extremely important                Critically important
# 25  Extremely important                  Somewhat important
# 26                  NaN                  Somewhat important
# 27                  NaN                                 NaN
# 28                  NaN                                 NaN
# 29  Extremely important                  Somewhat important
# 30  Extremely important                                 NaN
# 31                  NaN                  Somewhat important
# 32              Neutral                  Somewhat important
# 33                  NaN                      Very important
# 34                  NaN                                 NaN
# 35              Neutral                  Somewhat important
# 36   Somewhat important                      Very important
# 37   Somewhat important                    Fairly important
# 38                  NaN  Not at all important/not necessary
# 39                  NaN                                 NaN
# 40              Neutral                      Very important
# 41   Somewhat important  Not at all important/not necessary
# 42  Extremely important                      Very important
# 43   Somewhat important                      Very important
# 44  Extremely important                      Very important
# 45  Extremely important                    Fairly important
#
#                                            NEWJobHunt  \
# 16  Having a bad day (or week or month) at work;Be...
# 17                                Looking to relocate
# 18  Having a bad day (or week or month) at work;Tr...
# 19  Having a bad day (or week or month) at work;Be...
# 20                                                NaN
# 21  Better compensation;Better work/life balance;W...
# 22  Curious about other opportunities;Better compe...
# 23  Having a bad day (or week or month) at work;Cu...
# 24  Curious about other opportunities;Growth or le...
# 25  Curious about other opportunities;Better compe...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  Curious about other opportunities;Better compe...
# 30        Having a bad day (or week or month) at work
# 31  Better compensation;Growth or leadership oppor...
# 32  Just because;Curious about other opportunities...
# 33  Better compensation;Wanting to work with new t...
# 34                                                NaN
# 35  Having a bad day (or week or month) at work;Cu...
# 36                                Better compensation
# 37                  Curious about other opportunities
# 38                                Better compensation
# 39                                                NaN
# 40  Better compensation;Wanting to work with new t...
# 41  Curious about other opportunities;Better compe...
# 42                                                NaN
# 43  Having a bad day (or week or month) at work;Cu...
# 44  Better compensation;Better work/life balance;W...
# 45  Better compensation;Trouble with my teammates;...
#
#                                    NEWJobHuntResearch              NEWLearn  \
# 16  Company reviews from third party sites (e.g. G...           Once a year
# 17                                                NaN  Once every few years
# 18  Company reviews from third party sites (e.g. G...           Once a year
# 19               Personal network - friends or family  Once every few years
# 20                                                NaN      Every few months
# 21  Company reviews from third party sites (e.g. G...      Every few months
# 22  Company reviews from third party sites (e.g. G...      Every few months
# 23                                                NaN      Every few months
# 24                                                NaN  Once every few years
# 25  Read company media, such as employee blogs or ...  Once every few years
# 26                                                NaN  Once every few years
# 27                                                NaN      Every few months
# 28                                                NaN      Every few months
# 29  Read company media, such as employee blogs or ...                   NaN
# 30                                                NaN  Once every few years
# 31  Personal network - friends or family;Read othe...      Every few months
# 32  Company reviews from third party sites (e.g. G...           Once a year
# 33  Read company media, such as employee blogs or ...           Once a year
# 34                                                NaN           Once a year
# 35                                                NaN      Every few months
# 36  Directly asking current or past employees at t...           Once a year
# 37  Company reviews from third party sites (e.g. G...      Every few months
# 38  Company reviews from third party sites (e.g. G...  Once every few years
# 39                                                NaN           Once a year
# 40  Read company media, such as employee blogs or ...           Once a year
# 41  Read company media, such as employee blogs or ...  Once every few years
# 42                                                NaN           Once a year
# 43  Company reviews from third party sites (e.g. G...  Once every few years
# 44  Company reviews from third party sites (e.g. G...           Once a year
# 45  Read company media, such as employee blogs or ...           Once a year
#
#    NEWOffTopic                NEWOnboardGood NEWOtherComms  \
# 16    Not sure                            No            No
# 17         Yes  Onboarding? What onboarding?           Yes
# 18         Yes                            No            No
# 19    Not sure                            No            No
# 20         Yes                           NaN           Yes
# 21          No                           Yes            No
# 22          No  Onboarding? What onboarding?            No
# 23          No                           Yes           Yes
# 24         Yes                           Yes            No
# 25    Not sure                           Yes            No
# 26          No                           NaN           Yes
# 27          No                           NaN            No
# 28         NaN                           NaN            No
# 29          No  Onboarding? What onboarding?            No
# 30         NaN                           Yes           Yes
# 31         Yes                            No            No
# 32          No                            No            No
# 33         Yes                           NaN           Yes
# 34         NaN                           NaN           Yes
# 35          No                           Yes            No
# 36          No                           Yes            No
# 37          No                           Yes            No
# 38          No                           NaN            No
# 39    Not sure                           NaN            No
# 40          No                            No            No
# 41         Yes                           Yes           Yes
# 42          No                           Yes            No
# 43          No                            No            No
# 44          No  Onboarding? What onboarding?           Yes
# 45    Not sure                           Yes           Yes
#
#                                           NEWOvertime  \
# 16                  Rarely: 1-2 days per year or less
# 17  Occasionally: 1-2 days per quarter but less th...
# 18  Occasionally: 1-2 days per quarter but less th...
# 19                   Often: 1-2 days per week or more
# 20                                                NaN
# 21                   Often: 1-2 days per week or more
# 22                  Rarely: 1-2 days per year or less
# 23                   Often: 1-2 days per week or more
# 24                   Often: 1-2 days per week or more
# 25                                              Never
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  Occasionally: 1-2 days per quarter but less th...
# 30  Occasionally: 1-2 days per quarter but less th...
# 31                  Rarely: 1-2 days per year or less
# 32  Sometimes: 1-2 days per month but less than we...
# 33                                                NaN
# 34                                                NaN
# 35  Sometimes: 1-2 days per month but less than we...
# 36                   Often: 1-2 days per week or more
# 37  Sometimes: 1-2 days per month but less than we...
# 38                                              Never
# 39                                                NaN
# 40                                              Never
# 41                  Rarely: 1-2 days per year or less
# 42  Sometimes: 1-2 days per month but less than we...
# 43                   Often: 1-2 days per week or more
# 44  Sometimes: 1-2 days per month but less than we...
# 45  Sometimes: 1-2 days per month but less than we...
#
#                                   NEWPurchaseResearch      NEWPurpleLink  \
# 16                                                NaN  Hello, old friend
# 17  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 18                                                NaN  Hello, old friend
# 19                                                NaN  Hello, old friend
# 20                                                NaN  Hello, old friend
# 21                                                NaN                NaN
# 22  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 23  Start a free trial;Ask developers I know/work ...             Amused
# 24                                                NaN  Hello, old friend
# 25                                                NaN  Hello, old friend
# 26  Ask developers I know/work with;Visit develope...            Annoyed
# 27  Research companies that have advertised on sit...  Hello, old friend
# 28                                 Start a free trial            Annoyed
# 29  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 30                    Ask developers I know/work with                NaN
# 31  Ask developers I know/work with;Visit develope...  Hello, old friend
# 32  Ask developers I know/work with;Visit develope...  Hello, old friend
# 33  Ask developers I know/work with;Visit develope...             Amused
# 34  Visit developer communities like Stack Overflo...  Hello, old friend
# 35                                                NaN  Hello, old friend
# 36                                                NaN        Indifferent
# 37                                                NaN  Hello, old friend
# 38  Start a free trial;Visit developer communities...            Annoyed
# 39                                                NaN                NaN
# 40  Start a free trial;Visit developer communities...  Hello, old friend
# 41  Start a free trial;Ask developers I know/work ...             Amused
# 42  Start a free trial;Visit developer communities...             Amused
# 43  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 44                                                NaN            Annoyed
# 45  Ask developers I know/work with;Visit develope...  Hello, old friend
#
#                                            NEWSOSites  \
# 16  Stack Overflow (public Q&A for anyone who code...
# 17  Stack Overflow (public Q&A for anyone who code...
# 18  Stack Overflow (public Q&A for anyone who code...
# 19   Stack Overflow (public Q&A for anyone who codes)
# 20  Stack Overflow (public Q&A for anyone who code...
# 21  Stack Overflow (public Q&A for anyone who code...
# 22  Stack Overflow (public Q&A for anyone who code...
# 23   Stack Overflow (public Q&A for anyone who codes)
# 24  Stack Overflow (public Q&A for anyone who code...
# 25  Stack Overflow (public Q&A for anyone who code...
# 26   Stack Overflow (public Q&A for anyone who codes)
# 27  Stack Overflow (public Q&A for anyone who code...
# 28   Stack Overflow (public Q&A for anyone who codes)
# 29  Stack Overflow (public Q&A for anyone who code...
# 30   Stack Overflow (public Q&A for anyone who codes)
# 31  Stack Overflow (public Q&A for anyone who code...
# 32  Stack Overflow (public Q&A for anyone who code...
# 33  Stack Overflow (public Q&A for anyone who code...
# 34  Stack Overflow (public Q&A for anyone who code...
# 35  Stack Overflow (public Q&A for anyone who code...
# 36  Stack Overflow (public Q&A for anyone who code...
# 37   Stack Overflow (public Q&A for anyone who codes)
# 38  Stack Overflow (public Q&A for anyone who code...
# 39  Stack Overflow (public Q&A for anyone who code...
# 40  Stack Overflow (public Q&A for anyone who code...
# 41  Stack Overflow (public Q&A for anyone who code...
# 42   Stack Overflow (public Q&A for anyone who codes)
# 43  Stack Overflow (public Q&A for anyone who code...
# 44  Stack Overflow (public Q&A for anyone who code...
# 45  Stack Overflow (public Q&A for anyone who code...
#
#                                              NEWStuck        OpSys  \
# 16  Call a coworker or friend;Visit Stack Overflow...      Windows
# 17  Play games;Visit Stack Overflow;Do other work ...  Linux-based
# 18  Call a coworker or friend;Visit Stack Overflow...      Windows
# 19  Meditate;Call a coworker or friend;Go for a wa...      Windows
# 20  Visit Stack Overflow;Watch help / tutorial videos        MacOS
# 21                                                NaN      Windows
# 22  Play games;Call a coworker or friend;Visit Sta...      Windows
# 23  Call a coworker or friend;Visit Stack Overflow...  Linux-based
# 24                               Visit Stack Overflow      Windows
# 25  Play games;Call a coworker or friend;Visit Sta...        MacOS
# 26     Call a coworker or friend;Visit Stack Overflow  Linux-based
# 27  Visit Stack Overflow;Do other work and come ba...      Windows
# 28  Meditate;Play games;Call a coworker or friend;...      Windows
# 29  Play games;Call a coworker or friend;Visit Sta...      Windows
# 30                                                NaN  Linux-based
# 31  Meditate;Play games;Visit Stack Overflow;Go fo...      Windows
# 32  Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 33  Call a coworker or friend;Visit Stack Overflow...      Windows
# 34  Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 35  Visit Stack Overflow;Go for a walk or other ph...      Windows
# 36     Call a coworker or friend;Visit Stack Overflow      Windows
# 37  Call a coworker or friend;Do other work and co...        MacOS
# 38  Visit Stack Overflow;Watch help / tutorial videos      Windows
# 39                                                NaN      Windows
# 40  Visit Stack Overflow;Do other work and come ba...      Windows
# 41  Visit Stack Overflow;Go for a walk or other ph...      Windows
# 42  Visit Stack Overflow;Watch help / tutorial videos      Windows
# 43  Call a coworker or friend;Visit Stack Overflow...      Windows
# 44  Call a coworker or friend;Visit Stack Overflow...      Windows
# 45  Call a coworker or friend;Visit Stack Overflow...      Windows
#
#                                               OrgSize  \
# 16                                 20 to 99 employees
# 17                               100 to 499 employees
# 18                           10,000 or more employees
# ...
# 18     I have little or no influence  Straight / Heterosexual       Yes
# 19     I have little or no influence  Straight / Heterosexual       Yes
# 20                               NaN  Straight / Heterosexual       Yes
# 21                               NaN                      NaN       Yes
# 22  I have a great deal of influence  Straight / Heterosexual       Yes
# 23             I have some influence  Straight / Heterosexual       Yes
# 24     I have little or no influence  Straight / Heterosexual       Yes
# 25     I have little or no influence                      NaN       Yes
# 26                               NaN  Straight / Heterosexual       Yes
# 27                               NaN  Straight / Heterosexual       Yes
# 28                               NaN  Straight / Heterosexual       Yes
# 29             I have some influence  Straight / Heterosexual       Yes
# 30                               NaN                      NaN       Yes
# 31             I have some influence  Straight / Heterosexual       Yes
# 32             I have some influence  Straight / Heterosexual       Yes
# 33                               NaN           Gay or Lesbian       Yes
# 34                               NaN  Straight / Heterosexual       Yes
# 35     I have little or no influence  Straight / Heterosexual       Yes
# 36     I have little or no influence  Straight / Heterosexual       Yes
# 37     I have little or no influence  Straight / Heterosexual       Yes
# 38                               NaN                      NaN       Yes
# 39                               NaN  Straight / Heterosexual       Yes
# 40             I have some influence                      NaN       Yes
# 41             I have some influence  Straight / Heterosexual       Yes
# 42             I have some influence                      NaN       Yes
# 43             I have some influence  Straight / Heterosexual       Yes
# 44     I have little or no influence  Straight / Heterosexual       Yes
# 45  I have a great deal of influence                    Queer       Yes
#
#              SOComm                                         SOPartFreq  \
# 16   No, not at all  I have never participated in Q&A on Stack Over...
# 17    Yes, somewhat  I have never participated in Q&A on Stack Over...
# 18          Neutral                Less than once per month or monthly
# 19    Yes, somewhat                    A few times per month or weekly
# 20    Yes, somewhat                Less than once per month or monthly
# 21  Yes, definitely                             Multiple times per day
# 22    Yes, somewhat                Less than once per month or monthly
# 23  Yes, definitely                              Daily or almost daily
# 24  Yes, definitely                             Multiple times per day
# 25    Yes, somewhat                    A few times per month or weekly
# 26    Yes, somewhat                               A few times per week
# 27    Yes, somewhat                              Daily or almost daily
# 28   No, not at all                Less than once per month or monthly
# 29    Yes, somewhat                               A few times per week
# 30              NaN                    A few times per month or weekly
# 31  Yes, definitely                             Multiple times per day
# 32          Neutral                Less than once per month or monthly
# 33    Yes, somewhat                             Multiple times per day
# 34    Yes, somewhat                Less than once per month or monthly
# 35    Yes, somewhat                Less than once per month or monthly
# 36    Yes, somewhat                    A few times per month or weekly
# 37  Yes, definitely                Less than once per month or monthly
# 38   No, not really                    A few times per month or weekly
# 39   No, not really  I have never participated in Q&A on Stack Over...
# 40          Neutral                              Daily or almost daily
# 41   No, not really                Less than once per month or monthly
# 42  Yes, definitely                              Daily or almost daily
# 43    Yes, somewhat                    A few times per month or weekly
# 44          Neutral                Less than once per month or monthly
# 45    Yes, somewhat                    A few times per month or weekly
#
#                         SOVisitFreq                  SurveyEase  \
# 16            Daily or almost daily                        Easy
# 17            Daily or almost daily  Neither easy nor difficult
# 18             A few times per week                        Easy
# 19           Multiple times per day                        Easy
# 20            Daily or almost daily  Neither easy nor difficult
# 21           Multiple times per day                        Easy
# 22            Daily or almost daily                        Easy
# 23           Multiple times per day                        Easy
# 24           Multiple times per day  Neither easy nor difficult
# 25            Daily or almost daily                        Easy
# 26            Daily or almost daily                        Easy
# 27            Daily or almost daily  Neither easy nor difficult
# 28  A few times per month or weekly  Neither easy nor difficult
# 29            Daily or almost daily  Neither easy nor difficult
# 30           Multiple times per day                        Easy
# 31           Multiple times per day  Neither easy nor difficult
# 32            Daily or almost daily  Neither easy nor difficult
# 33           Multiple times per day                        Easy
# 34  A few times per month or weekly                        Easy
# 35           Multiple times per day                        Easy
# 36           Multiple times per day                        Easy
# 37             A few times per week                        Easy
# 38  A few times per month or weekly                        Easy
# 39  A few times per month or weekly                        Easy
# 40            Daily or almost daily                         NaN
# 41  A few times per month or weekly                        Easy
# 42           Multiple times per day                        Easy
# 43           Multiple times per day  Neither easy nor difficult
# 44           Multiple times per day                        Easy
# 45            Daily or almost daily  Neither easy nor difficult
#
#              SurveyLength Trans  \
# 16  Appropriate in length    No
# 17  Appropriate in length    No
# 18  Appropriate in length    No
# 19              Too short    No
# 20  Appropriate in length    No
# 21  Appropriate in length   NaN
# 22  Appropriate in length    No
# 23  Appropriate in length    No
# 24  Appropriate in length    No
# 25               Too long    No
# 26  Appropriate in length    No
# 27               Too long    No
# 28  Appropriate in length    No
# 29               Too long    No
# 30  Appropriate in length   Yes
# 31               Too long    No
# 32  Appropriate in length    No
# 33  Appropriate in length    No
# 34               Too long    No
# 35  Appropriate in length    No
# 36               Too long    No
# 37  Appropriate in length    No
# 38  Appropriate in length   NaN
# 39  Appropriate in length    No
# 40                    NaN   NaN
# 41  Appropriate in length    No
# 42  Appropriate in length   NaN
# 43  Appropriate in length    No
# 44               Too long    No
# 45  Appropriate in length    No
#
#                                        UndergradMajor  \
# 16  Computer science, computer engineering, or sof...
# 17  Computer science, computer engineering, or sof...
# 18  Computer science, computer engineering, or sof...
# 19  Another engineering discipline (such as civil,...
# 20                                                NaN
# 21  Computer science, computer engineering, or sof...
# 22  Another engineering discipline (such as civil,...
# 23  Another engineering discipline (such as civil,...
# 24  Computer science, computer engineering, or sof...
# 25  Computer science, computer engineering, or sof...
# 26  A humanities discipline (such as literature, h...
# 27  A health science (such as nursing, pharmacy, r...
# 28                                                NaN
# 29  Information systems, information technology, o...
# 30  Computer science, computer engineering, or sof...
# 31  Computer science, computer engineering, or sof...
# 32  Computer science, computer engineering, or sof...
# 33  Computer science, computer engineering, or sof...
# 34  Information systems, information technology, o...
# 35  Computer science, computer engineering, or sof...
# 36                      Web development or web design
# 37  Computer science, computer engineering, or sof...
# 38                                                NaN
# 39                                                NaN
# 40  Computer science, computer engineering, or sof...
# 41  Computer science, computer engineering, or sof...
# 42  Computer science, computer engineering, or sof...
# 43  Another engineering discipline (such as civil,...
# 44  Computer science, computer engineering, or sof...
# 45  Computer science, computer engineering, or sof...
#
#                                WebframeDesireNextYear  \
# 16                ASP.NET Core;Gatsby;React.js;Vue.js
# 17                                                NaN
# 18                            Django;Express;React.js
# 19                                             Spring
# 20                      Gatsby;React.js;Spring;Vue.js
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                              Flask
# 27                                                NaN
# 28  Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery...
# 29                            Express;React.js;Vue.js
# 30                                                NaN
# 31                                                NaN
# 32              Express;Gatsby;React.js;Ruby on Rails
# 33                    Angular;Express;React.js;Spring
# 34  Angular;Angular.js;Express;jQuery;React.js;Vue.js
# 35                                   Express;React.js
# 36                                             Gatsby
# 37                            Express;Gatsby;React.js
# 38                                                NaN
# 39                                                NaN
# 40                                             Vue.js
# 41                                ASP.NET Core;Spring
# 42                                                NaN
# 43                                                NaN
# 44                                      Angular;Flask
# 45                                                NaN
#
#                               WebframeWorkedWith  \
# 16         ASP.NET;Gatsby;jQuery;React.js;Vue.js
# 17                                           NaN
# 18               Angular;Angular.js;ASP.NET Core
# 19                             Angular.js;Spring
# 20  Angular;ASP.NET Core;Express;React.js;Spring
# 21                                           NaN
# 22                                           NaN
# 23                                           NaN
# 24                                           NaN
# 25                               Django;React.js
# 26                                         Flask
# 27                                           NaN
# 28                                           NaN
# 29                                Express;Vue.js
# 30                                           NaN
# 31                                           NaN
# 32    Angular;Angular.js;Django;Express;React.js
# 33                               Angular;Express
# 34                                Express;jQuery
# 35                              Express;React.js
# 36                Express;jQuery;React.js;Vue.js
# 37                       Express;Gatsby;React.js
# 38                                           NaN
# 39                                           NaN
# 40                                ASP.NET;Vue.js
# 41                 ASP.NET;Flask;React.js;Spring
# 42                                       ASP.NET
# 43                                           NaN
# 44                   Angular;Flask;jQuery;Spring
# 45                                           NaN
#
#                                         WelcomeChange  WorkWeekHrs  \
# 16            Just as welcome now as I felt last year         40.0
# 17            Just as welcome now as I felt last year         45.0
# 18            Just as welcome now as I felt last year         35.0
# 19            Just as welcome now as I felt last year         50.0
# 20                                                NaN          NaN
# 21            Just as welcome now as I felt last year         50.0
# 22           Somewhat less welcome now than last year         40.0
# 23            Just as welcome now as I felt last year         42.0
# 24            Just as welcome now as I felt last year         40.0
# 25            Just as welcome now as I felt last year         40.0
# 26            Just as welcome now as I felt last year          NaN
# 27            Just as welcome now as I felt last year          NaN
# 28  Not applicable - I did not use Stack Overflow ...          NaN
# 29              A lot less welcome now than last year         37.0
# 30                                                NaN          NaN
# 31            Just as welcome now as I felt last year         37.0
# 32            Just as welcome now as I felt last year         40.0
# 33           Somewhat more welcome now than last year          NaN
# 34            Just as welcome now as I felt last year          NaN
# 35            Just as welcome now as I felt last year         40.0
# 36           Somewhat more welcome now than last year         39.0
# 37            Just as welcome now as I felt last year         40.0
# 38            Just as welcome now as I felt last year          NaN
# 39            Just as welcome now as I felt last year          NaN
# 40              A lot less welcome now than last year         40.0
# 41           Somewhat less welcome now than last year         37.0
# 42            Just as welcome now as I felt last year         45.0
# 43            Just as welcome now as I felt last year         45.0
# 44              A lot less welcome now than last year         35.0
# 45           Somewhat more welcome now than last year         35.0
#
#            YearsCode YearsCodePro
# 16                 7            3
# 17                19           12
# 18                 9            3
# 19                22           17
# 20                 7          NaN
# 21                10            2
# 22                 8            3
# 23                30           20
# 24                23           18
# 25                17           10
# 26                20           20
# 27                 2          NaN
# 28  Less than 1 year          NaN
# 29                 4            2
# 30                 6            3
# 31                19           10
# 32                20           14
# 33                10          NaN
# 34                 3          NaN
# 35                 4            3
# 36                 2            1
# 37                20           12
# 38                13            1
# 39                 6          NaN
# 40                25           20
# 41                16           10
# 42                36           29
# 43                10            6
# 44                 9            2
# 45                 6            4

# %%
schema_df.loc['Hobbyist', 'QuestionText']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 schema_df.loc['Hobbyist', 'QuestionText']
#
# File C:\Program Files\Python310\lib\site-packages\pandas\core\indexing.py:960, in _LocationIndexer.__getitem__(self, key)
#     958     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959     if self._is_scalar_access(key):
# --> 960         return self.obj._get_value(*key, takeable=self._takeable)
#     961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#
# File C:\Program Files\Python310\lib\site-packages\pandas\core\frame.py:3622, in DataFrame._get_value(self, index, col, takeable)
#    3616 engine = self.index._engine
#    3618 if not isinstance(self.index, MultiIndex):
#    3619     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    3620     #  results if our categories are integers that dont match our codes
#    3621     # IntervalIndex: IntervalTree has no get_loc
# -> 3622     row = self.index.get_loc(index)
#    3623     return series._values[row]
#    3625 # For MultiIndex going through engine effectively restricts us to
#    3626 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File C:\Program Files\Python310\lib\site-packages\pandas\core\indexes\range.py:389, in RangeIndex.get_loc(self, key, method, tolerance)
#     387             raise KeyError(key) from err
#     388     self._check_indexing_error(key)
# --> 389     raise KeyError(key)
#     390 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'Hobbyist'
